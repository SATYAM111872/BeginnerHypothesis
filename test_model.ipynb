# %%
import os
import json
import numpy as np
import tensorflow as tf
import cv2
from concurrent.futures import ThreadPoolExecutor
from keras import layers

class ULSAMLayer(layers.Layer):
    def __init__(self, groups=8, **kwargs):
        super(ULSAMLayer, self).__init__(**kwargs)
        self.groups = groups
        self.depthwise_conv = layers.DepthwiseConv2D(kernel_size=1, strides=1, padding='same')
        self.max_pool = layers.MaxPooling2D(pool_size=3, strides=1, padding='same')
        self.conv = layers.Conv2D(filters=80, kernel_size=1, strides=1, padding='same')

    def call(self, input_tensor):
        channels = input_tensor.shape[-1]
        group_size = channels // self.groups
        splits = tf.split(input_tensor, num_or_size_splits=self.groups, axis=-1)
        output_splits = []
        for split in splits:
            processed_split = self.process_split(split, group_size)
            output_splits.append(processed_split)
        return tf.concat(output_splits, axis=-1)

    def process_split(self, split, group_size):
        x = self.depthwise_conv(split)
        x = self.max_pool(x)
        x = self.conv(x)
        return x

def get_bounding_box(cam, img_size=(224, 224), threshold=0.5):
    cam_resized = cv2.resize(cam, img_size)
    binary = (cam_resized > threshold).astype(np.uint8)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    if not contours:
        return 0.0, 0.0, 0.0, 0.0
    
    largest_contour = max(contours, key=cv2.contourArea)
    x, y, w, h = cv2.boundingRect(largest_contour)
    
    x_norm = x / img_size[0]
    y_norm = y / img_size[1]
    w_norm = w / img_size[0]
    h_norm = h / img_size[1]
    
    return (x_norm, y_norm, w_norm, h_norm)

def generate_cam(img, class_idx, cam_model):
    if not isinstance(img, tf.Tensor):
        img = tf.convert_to_tensor(img, dtype=tf.float32)
    
    with tf.GradientTape() as tape:
        tape.watch(img)
        conv_output, predictions = cam_model(img)
        loss = predictions[0, class_idx]
    
    grads = tape.gradient(loss, conv_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    cam = tf.reduce_sum(tf.multiply(pooled_grads, conv_output), axis=-1)
    cam = tf.maximum(cam, 0)
    
    if tf.reduce_max(cam) > 0:
        cam = cam / tf.reduce_max(cam)
    cam = tf.squeeze(cam)
    
    return cam.numpy()

def parse_image(img_path):
    print(f"Parsing image: {os.path.basename(img_path)}")
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, (224, 224))
    img = tf.cast(img, tf.float32) / 255.0
    return np.expand_dims(img, axis=0)

def read_mapping(file_path):
    print(f"Reading mapping file from: {file_path}")
    mapping = {}
    with open(file_path, 'r') as f:
        for line in f:
            if line.strip() and not line.startswith("#"):
                try:
                    values = line.split(",")
                    triplet = int(values[0].strip())
                    instrument = int(values[1].strip())
                    target = int(values[2].strip())
                    verb = int(values[3].strip())
                    mapping[triplet] = (instrument, target, verb)
                except ValueError:
                    continue
    print(f"Loaded {len(mapping)} triplet mappings")
    return mapping

def process_frame(args):
    """Process a single frame"""
    image_path, model, cam_model, triplet_mapping = args
    frame_id = str(int(os.path.basename(image_path).split(".")[0]))
    print(f"Processing frame {frame_id}")
    
    try:
        image = parse_image(image_path)
        
        print(f"Running model inference for frame {frame_id}")
        model_output = model(tf.convert_to_tensor(image))
        
        recognition = model_output[1][0].numpy().tolist()
        confidence_indices = [(idx, conf.numpy()) for idx, conf in enumerate(model_output[1][0]) if conf > 0.5]
        print(f"Found {len(confidence_indices)} confident predictions in frame {frame_id}")
        
        list_triplet = []
        for idx, confidence in confidence_indices:
            print(f"Processing triplet {idx} with confidence {confidence:.3f} in frame {frame_id}")
            triplet_id = triplet_mapping[idx]
            instrument_idx = triplet_id[0]
            cam = generate_cam(image, instrument_idx, cam_model)
            bbox_x, bbox_y, bbox_w, bbox_h = get_bounding_box(cam)
            tool_prob = float(model_output[0][0][instrument_idx].numpy())
            
            list_triplet.append({
                "triplet": idx,
                "instrument": [instrument_idx, tool_prob, bbox_x, bbox_y, bbox_w, bbox_h]
            })
        
        result = {
            "detection": list_triplet,
            "recognition": recognition
        }
        
        print(f"Completed processing frame {frame_id}")
        return frame_id, result
        
    except Exception as e:
        print(f"Error processing frame {frame_id}: {str(e)}")
        return frame_id, None

def process_video(video_folder, base_path, model, cam_model, triplet_mapping, max_workers=None):
    """Process all frames of a video in parallel"""
    print(f"\nStarting processing of video: {video_folder}")
    video_path = os.path.join(base_path, video_folder)
    video_dict = {}
    
    # Get all image paths
    image_paths = [os.path.join(video_path, f) for f in sorted(os.listdir(video_path))]
    print(f"Found {len(image_paths)} frames in {video_folder}")
    
    # Create arguments for parallel processing
    process_args = [(path, model, cam_model, triplet_mapping) for path in image_paths]
    
    # Process all frames in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        results = executor.map(process_frame, process_args)
        
        for frame_id, result in results:
            if result is not None:
                video_dict[frame_id] = result
    
    print(f"Completed processing video: {video_folder}")
    return video_dict

def main():
    print("Starting main execution")
    
    base_path = r"C:\Users\satya\OneDrive\Desktop\projects\BH\test\videos"
    desired_order = ["VID92", "VID96", "VID103", "VID110", "VID111"]
    file_path = r"C:\Users\satya\OneDrive\Desktop\projects\BH\dict\maps.txt"
    
    print("Loading model...")
    model = tf.keras.models.load_model(
        r"C:\Users\satya\OneDrive\Desktop\projects\BH\model_final.h5",
        custom_objects={'ULSAMLayer': ULSAMLayer}
    )
    print("Model loaded successfully")
    
    print("Creating CAM model...")
    cam_model = tf.keras.Model(
        inputs=model.input,
        outputs=[model.get_layer('re_lu_34').output, model.get_layer('instrument_output').output]
    )
    print("CAM model created")
    
    triplet_mapping = read_mapping(file_path)
    
    print(f"\nStarting video processing for {len(desired_order)} videos")
    overall_dict = {}
    
    # Process videos in parallel
    with ThreadPoolExecutor(max_workers=len(desired_order)) as executor:
        print("Initialized thread pool executor")
        future_to_video = {
            executor.submit(
                process_video, 
                video_folder, 
                base_path, 
                model, 
                cam_model, 
                triplet_mapping,
                os.cpu_count()  # Use all available CPU cores for frame processing
            ): video_folder 
            for video_folder in desired_order
        }
        
        for future in future_to_video:
            video_folder = future_to_video[future]
            try:
                print(f"\nWaiting for results from video {video_folder}")
                video_dict = future.result()
                overall_dict[video_folder] = video_dict
                print(f"Completed processing video {video_folder}")
            except Exception as e:
                print(f"Error processing video {video_folder}: {str(e)}")
    
    print("\nSaving results to video_predictions.json")
    with open("video_prediction.json", "w") as f:
        json.dump(overall_dict, f, indent=2)
        print("Processing completed successfully")
    return overall_dict

overall_dict=main()
# Out:
# Starting main execution
# Loading model...
# WARNING:tensorflow:From c:\Users\satya\OneDrive\Desktop\projects\BH\BHenv\Lib\site-packages\keras\src\backend\tensorflow\core.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully
# Creating CAM model...
# CAM model created
# Reading mapping file from: C:\Users\satya\OneDrive\Desktop\projects\BH\dict\maps.txt
# Loaded 100 triplet mappings
#
# Starting video processing for 5 videos
# Initialized thread pool executor
#
# Starting processing of video: VID92
#
# Starting processing of video: VID96
#
# Starting processing of video: VID103
#
# Starting processing of video: VID110
#
# Starting processing of video: VID111
#
# Waiting for results from video VID92
# Found 1707 frames in VID96
# Found 2124 frames in VID92
# Processing frame 0
# Parsing image: 000000.png
# Processing frame 0
# Parsing image: 000000.png
# Processing frame 1
# Parsing image: 000001.png
# Processing frame 1
# Parsing image: 000001.png
# Processing frame 2
# Parsing image: 000002.png
# Processing frame 2
# Parsing image: 000002.png
# Found 2146 frames in VID111
# Found 2220 frames in VID103
# Processing frame 3
# Parsing image: 000003.png
# Found 2177 frames in VID110
# Processing frame 4
# Parsing image: 000004.png
# Processing frame 5
# Parsing image: 000005.png
# Processing frame 0
# Parsing image: 000000.png
# Processing frame 0
# Parsing image: 000000.png
# Processing frame 0
# Parsing image: 000000.png
# Running model inference for frame 2
# Running model inference for frame 1
# Running model inference for frame 2
# Running model inference for frame 0
# Processing frame 1
# Parsing image: 000001.png
# Running model inference for frame 1
# Running model inference for frame 3
# Running model inference for frame 0
# Running model inference for frame 4
# Processing frame 2
# Parsing image: 000002.png
# Running model inference for frame 5
# Processing frame 1
# Parsing image: 000001.png
# Processing frame 1
# Parsing image: 000001.png
# Processing frame 3
# Parsing image: 000003.png
# Processing frame 4
# Parsing image: 000004.png
# Processing frame 5
# Parsing image: 000005.png
# Processing frame 2
# Parsing image: 000002.png
# Processing frame 3
# Parsing image: 000003.png
# Processing frame 4
# Parsing image: 000004.png
# Processing frame 3
# Parsing image: 000003.png
# Processing frame 6
# Parsing image: 000006.png
# Processing frame 2
# Parsing image: 000002.png
# Processing frame 3
# Parsing image: 000003.png
# Processing frame 5
# Parsing image: 000005.png
# Processing frame 4
# Parsing image: 000004.png
# Processing frame 7
# Parsing image: 000007.png
# Processing frame 8
# Parsing image: 000008.png
# Processing frame 9
# Parsing image: 000009.png
# Processing frame 10
# Parsing image: 000010.png
# Processing frame 11
# Parsing image: 000011.png
# Processing frame 6
# Parsing image: 000006.png
# Processing frame 4
# Parsing image: 000004.png
# Processing frame 5
# Parsing image: 000005.png
# Processing frame 6
# Parsing image: 000006.png
# Processing frame 7
# Parsing image: 000007.png
# Processing frame 8
# Parsing image: 000008.png
# Running model inference for frame 8
# Running model inference for frame 0
# Running model inference for frame 5
# Running model inference for frame 3
# Running model inference for frame 6
# Running model inference for frame 4
# Running model inference for frame 3
# Running model inference for frame 3
# Running model inference for frame 2
# Running model inference for frame 5
# Running model inference for frame 7
# Running model inference for frame 4
# Running model inference for frame 1
# Running model inference for frame 4
# Running model inference for frame 0
# Processing frame 6
# Parsing image: 000006.png
# Running model inference for frame 2
# Running model inference for frame 1
# Running model inference for frame 1
# Running model inference for frame 2
# Running model inference for frame 0
# Running model inference for frame 3
# Processing frame 5
# Parsing image: 000005.png
# Running model inference for frame 9
# Running model inference for frame 5
# Processing frame 7
# Parsing image: 000007.png
# Running model inference for frame 6
# Running model inference for frame 7
# Running model inference for frame 6
# Processing frame 8
# Parsing image: 000008.png
# Running model inference for frame 4
# Running model inference for frame 8
# Running model inference for frame 11
# Processing frame 9
# Parsing image: 000009.png
# Processing frame 6
# Parsing image: 000006.png
# Running model inference for frame 10
# Running model inference for frame 6
# Processing frame 7
# Parsing image: 000007.png
# Running model inference for frame 7
# Running model inference for frame 5
# Processing frame 8
# Parsing image: 000008.png
# Running model inference for frame 8
# Processing frame 9
# Parsing image: 000009.png
# Running model inference for frame 9
# Processing frame 10
# Parsing image: 000010.png
# Running model inference for frame 6
# Processing frame 11
# Parsing image: 000011.png
# Running model inference for frame 7
# Processing frame 9
# Parsing image: 000009.png
# Running model inference for frame 8
# Processing frame 10
# Parsing image: 000010.png
# Running model inference for frame 9
# Running model inference for frame 11
# Processing frame 10
# Parsing image: 000010.png
# Running model inference for frame 9
# Processing frame 11
# Parsing image: 000011.png
# Processing frame 7
# Parsing image: 000007.png
# Running model inference for frame 10
# Processing frame 8
# Parsing image: 000008.png
# Running model inference for frame 10
# Running model inference for frame 10
# Processing frame 9
# Parsing image: 000009.png
# Processing frame 11
# Parsing image: 000011.png
# Running model inference for frame 7
# Running model inference for frame 11
# Processing frame 10
# Parsing image: 000010.png
# Running model inference for frame 8
# Running model inference for frame 9
# Running model inference for frame 10
# Processing frame 11
# Parsing image: 000011.png
# Running model inference for frame 11
# Running model inference for frame 11
# Found 1 confident predictions in frame 5
# Processing triplet 0 with confidence 0.703 in frame 5
# Found 2 confident predictions in frame 0
# Processing triplet 0 with confidence 0.680 in frame 0
# Found 1 confident predictions in frame 7
# Processing triplet 0 with confidence 0.703 in frame 7
# Found 2 confident predictions in frame 6
# Processing triplet 0 with confidence 0.770 in frame 6
# Found 1 confident predictions in frame 5
# Processing triplet 2 with confidence 0.541 in frame 5
# Found 2 confident predictions in frame 0
# Processing triplet 0 with confidence 0.530 in frame 0
# Found 1 confident predictions in frame 2
# Processing triplet 0 with confidence 0.703 in frame 2
# Found 2 confident predictions in frame 5
# Processing triplet 0 with confidence 0.547 in frame 5
# Found 1 confident predictions in frame 3
# Processing triplet 0 with confidence 0.703 in frame 3
# Found 1 confident predictions in frame 5
# Processing triplet 0 with confidence 0.831 in frame 5
# Found 1 confident predictions in frame 8
# Processing triplet 0 with confidence 0.770 in frame 8
# Found 2 confident predictions in frame 8
# Processing triplet 0 with confidence 0.740 in frame 8
# Found 2 confident predictions in frame 2
# Processing triplet 0 with confidence 0.511 in frame 2
# Found 1 confident predictions in frame 10
# Processing triplet 0 with confidence 0.671 in frame 10
# Found 1 confident predictions in frame 0
# Processing triplet 0 with confidence 0.703 in frame 0
# Found 1 confident predictions in frame 0
# Processing triplet 0 with confidence 0.844 in frame 0
# Found 1 confident predictions in frame 4
# Processing triplet 0 with confidence 0.703 in frame 4
# Found 1 confident predictions in frame 6
# Processing triplet 0 with confidence 0.787 in frame 6
# Found 1 confident predictions in frame 8
# Processing triplet 0 with confidence 0.875 in frame 8
# Found 1 confident predictions in frame 1
# Processing triplet 0 with confidence 0.703 in frame 1
# Found 1 confident predictions in frame 2
# Processing triplet 0 with confidence 0.703 in frame 2
# Found 1 confident predictions in frame 11
# Processing triplet 0 with confidence 0.731 in frame 11
# Found 1 confident predictions in frame 10
# Processing triplet 0 with confidence 0.692 in frame 10
# Found 1 confident predictions in frame 1
# Processing triplet 0 with confidence 0.759 in frame 1
# Found 1 confident predictions in frame 8
# Processing triplet 0 with confidence 0.787 in frame 8
# Found 1 confident predictions in frame 11
# Processing triplet 0 with confidence 0.703 in frame 11
# Found 2 confident predictions in frame 6
# Processing triplet 0 with confidence 0.727 in frame 6
# Found 1 confident predictions in frame 3
# Processing triplet 0 with confidence 0.782 in frame 3
# Found 2 confident predictions in frame 1
# Processing triplet 0 with confidence 0.696 in frame 1
# Found 1 confident predictions in frame 4
# Processing triplet 0 with confidence 0.886 in frame 4
# Found 2 confident predictions in frame 0
# Processing triplet 0 with confidence 0.753 in frame 0
# Found 2 confident predictions in frame 6
# Processing triplet 0 with confidence 0.732 in frame 6
# Found 1 confident predictions in frame 4
# Processing triplet 0 with confidence 0.703 in frame 4
# Found 2 confident predictions in frame 7
# Processing triplet 0 with confidence 0.731 in frame 7
# Found 2 confident predictions in frame 9
# Processing triplet 0 with confidence 0.602 in frame 9
# Found 2 confident predictions in frame 4
# Processing triplet 0 with confidence 0.661 in frame 4
# Found 1 confident predictions in frame 1
# Processing triplet 0 with confidence 0.706 in frame 1
# Found 2 confident predictions in frame 4
# Processing triplet 0 with confidence 0.719 in frame 4
# Found 1 confident predictions in frame 1
# Processing triplet 0 with confidence 0.772 in frame 1
# Found 2 confident predictions in frame 7
# Processing triplet 0 with confidence 0.704 in frame 7
# Found 1 confident predictions in frame 10
# Processing triplet 0 with confidence 0.703 in frame 10
# Found 2 confident predictions in frame 7
# Processing triplet 0 with confidence 0.697 in frame 7
# Found 2 confident predictions in frame 3
# Processing triplet 0 with confidence 0.782 in frame 3
# Found 1 confident predictions in frame 6
# Processing triplet 0 with confidence 0.703 in frame 6
# Found 1 confident predictions in frame 2
# Processing triplet 0 with confidence 0.687 in frame 2
# Found 2 confident predictions in frame 9
# Processing triplet 0 with confidence 0.808 in frame 9
# Found 1 confident predictions in frame 11
# Processing triplet 0 with confidence 0.853 in frame 11
# Found 1 confident predictions in frame 3
# Processing triplet 0 with confidence 0.785 in frame 3
# Found 1 confident predictions in frame 11
# Processing triplet 0 with confidence 0.731 in frame 11
# Found 1 confident predictions in frame 9
# Processing triplet 0 with confidence 0.615 in frame 9
# Found 1 confident predictions in frame 9
# Processing triplet 0 with confidence 0.703 in frame 9
# Found 1 confident predictions in frame 2
# Processing triplet 0 with confidence 0.636 in frame 2
# Found 1 confident predictions in frame 5
# Processing triplet 0 with confidence 0.884 in frame 5
# Found 1 confident predictions in frame 7
# Processing triplet 0 with confidence 0.768 in frame 7
# Found 1 confident predictions in frame 8
# Processing triplet 0 with confidence 0.703 in frame 8
# Found 1 confident predictions in frame 10
# Processing triplet 0 with confidence 0.641 in frame 10
# Found 1 confident predictions in frame 3
# Processing triplet 0 with confidence 0.703 in frame 3
# Found 1 confident predictions in frame 10
# Processing triplet 0 with confidence 0.799 in frame 10
# Found 1 confident predictions in frame 11
# Processing triplet 0 with confidence 0.671 in frame 11
# Found 2 confident predictions in frame 9
# Processing triplet 0 with confidence 0.792 in frame 9
# Completed processing frame 10Completed processing frame 8
# Processing frame 12
# Parsing image: 000012.png
#
# Processing frame 12
# Parsing image: 000012.png
# Running model inference for frame 12
# Running model inference for frame 12
# Completed processing frame 11
# Processing frame 13
# Parsing image: 000013.png
# Running model inference for frame 13
# Processing triplet 2 with confidence 0.628 in frame 4
# Completed processing frame 1
# Processing frame 13
# Parsing image: 000013.png
# Processing triplet 2 with confidence 0.688 in frame 0
# Completed processing frame 2
# Processing frame 12
# Parsing image: 000012.png
# Running model inference for frame 12
# Running model inference for frame 13
# Processing triplet 2 with confidence 0.573 in frame 6
# Completed processing frame 8
# Processing frame 13
# Parsing image: 000013.png
# Completed processing frame 10
# Processing frame 14
# Parsing image: 000014.png
# Running model inference for frame 13
# Running model inference for frame 14
# Completed processing frame 4
# Processing frame 14
# Parsing image: 000014.png
# Running model inference for frame 14
# Completed processing frame 11
# Completed processing frame 5
# Processing frame 14
# Parsing image: 000014.png
# Processing frame 15
# Parsing image: 000015.png
# Completed processing frame 11
# Processing frame 12
# Parsing image: 000012.png
# Completed processing frame 4
# Processing triplet 2 with confidence 0.567 in frame 7
# Processing frame 15
# Parsing image: 000015.png
# Running model inference for frame 15
# Running model inference for frame 14
# Running model inference for frame 12
# Running model inference for frame 15
# Completed processing frame 5
# Processing frame 13
# Parsing image: 000013.png
# Completed processing frame 8
# Processing frame 12
# Parsing image: 000012.png
# Running model inference for frame 12
# Running model inference for frame 13
# Completed processing frame 9
# Completed processing frame 6
# Processing frame 16
# Parsing image: 000016.png
# Processing frame 17
# Parsing image: 000017.png
# Completed processing frame 5
# Processing frame 13
# Parsing image: 000013.png
# Running model inference for frame 16
# Running model inference for frame 17
# Completed processing frame 10
# Running model inference for frame 13
# Processing frame 18
# Parsing image: 000018.png
# Running model inference for frame 18
# Completed processing frame 3
# Processing frame 14
# Parsing image: 000014.png
# Running model inference for frame 14
# Completed processing frame 3
# Processing frame 19
# Parsing image: 000019.png
# Running model inference for frame 19
# Completed processing frame 2
# Completed processing frame 2
# Completed processing frame 1
# Completed processing frame 11
# Processing frame 15
# Parsing image: 000015.png
# Processing frame 15
# Parsing image: 000015.png
# Processing frame 16
# Parsing image: 000016.png
# Processing frame 20
# Parsing image: 000020.png
# Running model inference for frame 16
# Running model inference for frame 15
# Running model inference for frame 20
# Running model inference for frame 15
# Processing triplet 6 with confidence 0.516 in frame 5
# Processing triplet 2 with confidence 0.638 in frame 0
# Completed processing frame 3
# Completed processing frame 4
# Processing frame 14
# Parsing image: 000014.png
# Processing frame 16
# Parsing image: 000016.png
# Processing triplet 2 with confidence 0.531 in frame 3
# Processing triplet 2 with confidence 0.558 in frame 2
# Running model inference for frame 16
# Running model inference for frame 14
# Completed processing frame 10
# Processing frame 17
# Parsing image: 000017.png
# Completed processing frame 0
# Processing frame 18
# Parsing image: 000018.png
# Running model inference for frame 17
# Running model inference for frame 18
# Completed processing frame 11
# Completed processing frame 0
# Processing frame 15
# Parsing image: 000015.png
# Processing triplet 2 with confidence 0.630 in frame 8
# Processing frame 16
# Parsing image: 000016.png
# Completed processing frame 1
# Running model inference for frame 16
# Running model inference for frame 15Processing frame 17
# Parsing image: 000017.png
#
# Running model inference for frame 17
# Processing triplet 2 with confidence 0.665 in frame 0
# Processing triplet 2 with confidence 0.743 in frame 1
# Completed processing frame 10
# Processing frame 16
# Parsing image: 000016.png
# Processing triplet 2 with confidence 0.698 in frame 7
# Running model inference for frame 16
# Completed processing frame 2
# Processing triplet 2 with confidence 0.510 in frame 9
# Processing frame 18
# Parsing image: 000018.png
# Processing triplet 2 with confidence 0.563 in frame 6
# Running model inference for frame 18
# Completed processing frame 7
# Processing frame 17
# Parsing image: 000017.png
# Processing triplet 2 with confidence 0.524 in frame 7
# Running model inference for frame 17
# Completed processing frame 1
# Processing frame 19
# Parsing image: 000019.png
# Completed processing frame 7
# Running model inference for frame 19
# Processing frame 20
# Parsing image: 000020.png
# Running model inference for frame 20
# Processing triplet 2 with confidence 0.543 in frame 9
# Completed processing frame 3
# Processing frame 19
# Parsing image: 000019.png
# Running model inference for frame 19
# Completed processing frame 6
# Completed processing frame 5
# Processing frame 18Processing frame 21
# Parsing image: 000021.png
#
# Parsing image: 000018.png
# Completed processing frame 9
# Running model inference for frame 21
# Running model inference for frame 18
# Processing frame 22
# Parsing image: 000022.png
# Running model inference for frame 22
# Processing triplet 2 with confidence 0.589 in frame 4
# Completed processing frame 8
# Processing frame 23
# Parsing image: 000023.png
# Running model inference for frame 23
# Processing triplet 2 with confidence 0.797 in frame 9
# Processing triplet 2 with confidence 0.554 in frame 6
# Found 1 confident predictions in frame 12
# Processing triplet 0 with confidence 0.582 in frame 12
# Found 1 confident predictions in frame 13
# Processing triplet 0 with confidence 0.839 in frame 13
# Found 1 confident predictions in frame 12
# Processing triplet 0 with confidence 0.759 in frame 12
# Found 2 confident predictions in frame 15
# Processing triplet 0 with confidence 0.624 in frame 15
# Found 2 confident predictions in frame 13
# Processing triplet 0 with confidence 0.624 in frame 13
# Found 1 confident predictions in frame 13
# Processing triplet 0 with confidence 0.714 in frame 13
# Found 2 confident predictions in frame 14
# Processing triplet 0 with confidence 0.739 in frame 14
# Found 1 confident predictions in frame 12
# Processing triplet 0 with confidence 0.799 in frame 12
# Found 2 confident predictions in frame 12
# Processing triplet 0 with confidence 0.726 in frame 12
# Found 1 confident predictions in frame 15
# Processing triplet 0 with confidence 0.606 in frame 15
# Found 2 confident predictions in frame 14
# Processing triplet 0 with confidence 0.588 in frame 14
# Found 2 confident predictions in frame 14
# Processing triplet 0 with confidence 0.790 in frame 14
# Found 1 confident predictions in frame 12
# Processing triplet 0 with confidence 0.703 in frame 12
# Found 1 confident predictions in frame 13
# Processing triplet 0 with confidence 0.703 in frame 13
# Found 2 confident predictions in frame 16
# Processing triplet 0 with confidence 0.648 in frame 16
# Found 1 confident predictions in frame 17
# Processing triplet 2 with confidence 0.634 in frame 17
# Found 2 confident predictions in frame 13
# Processing triplet 0 with confidence 0.763 in frame 13
# Found 1 confident predictions in frame 18
# Processing triplet 0 with confidence 0.915 in frame 18
# Found 1 confident predictions in frame 15
# Processing triplet 0 with confidence 0.703 in frame 15
# Found 1 confident predictions in frame 14
# Processing triplet 0 with confidence 0.703 in frame 14
# Found 1 confident predictions in frame 16
# Processing triplet 0 with confidence 0.613 in frame 16
# Found 1 confident predictions in frame 20
# Processing triplet 0 with confidence 0.713 in frame 20
# Found 1 confident predictions in frame 18
# Processing triplet 0 with confidence 0.703 in frame 18
# Found 1 confident predictions in frame 19
# Processing triplet 0 with confidence 0.798 in frame 19
# Found 1 confident predictions in frame 15
# Processing triplet 0 with confidence 0.519 in frame 15
# Found 1 confident predictions in frame 16
# Processing triplet 0 with confidence 0.703 in frame 16
# Found 2 confident predictions in frame 14
# Processing triplet 0 with confidence 0.694 in frame 14
# Found 1 confident predictions in frame 15
# Processing triplet 0 with confidence 0.586 in frame 15
# Found 1 confident predictions in frame 16
# Processing triplet 0 with confidence 0.773 in frame 16
# Found 2 confident predictions in frame 18
# Processing triplet 0 with confidence 0.846 in frame 18
# Found 2 confident predictions in frame 16
# Processing triplet 0 with confidence 0.544 in frame 16
# Found 2 confident predictions in frame 17
# Processing triplet 0 with confidence 0.801 in frame 17
# Found 1 confident predictions in frame 17
# Processing triplet 0 with confidence 0.703 in frame 17
# Found 1 confident predictions in frame 20
# Processing triplet 0 with confidence 0.703 in frame 20
# Found 1 confident predictions in frame 17
# Processing triplet 0 with confidence 0.545 in frame 17
# Found 1 confident predictions in frame 19
# Processing triplet 0 with confidence 0.703 in frame 19
# Found 1 confident predictions in frame 19
# Processing triplet 0 with confidence 0.841 in frame 19
# Found 1 confident predictions in frame 22
# Processing triplet 0 with confidence 0.703 in frame 22
# Found 1 confident predictions in frame 21
# Processing triplet 0 with confidence 0.703 in frame 21
# Found 1 confident predictions in frame 18
# Processing triplet 0 with confidence 0.703 in frame 18
# Found 1 confident predictions in frame 23
# Processing triplet 0 with confidence 0.703 in frame 23
# Completed processing frame 4
# Processing frame 17
# Parsing image: 000017.png
# Running model inference for frame 17
# Completed processing frame 6
# Processing frame 18
# Parsing image: 000018.png
# Running model inference for frame 18
# Completed processing frame 6
# Processing frame 20
# Parsing image: 000020.png
# Running model inference for frame 20
# Completed processing frame 8
# Processing frame 19
# Parsing image: 000019.png
# Running model inference for frame 19
# Completed processing frame 9
# Processing frame 20
# Parsing image: 000020.png
# Running model inference for frame 20
# Completed processing frame 3
# Processing frame 21
# Parsing image: 000021.png
# Running model inference for frame 21
# Completed processing frame 2
# Processing frame 19
# Parsing image: 000019.png
# Running model inference for frame 19
# Completed processing frame 7
# Processing frame 21
# Parsing image: 000021.png
# Running model inference for frame 21
# Completed processing frame 0
# Processing frame 22
# Parsing image: 000022.png
# Running model inference for frame 22
# Completed processing frame 7
# Processing frame 21
# Parsing image: 000021.png
# Running model inference for frame 21
# Completed processing frame 7
# Processing frame 20
# Parsing image: 000020.png
# Completed processing frame 9
# Running model inference for frame 20
# Processing frame 21
# Parsing image: 000021.png
# Running model inference for frame 21
# Completed processing frame 5
# Processing frame 22
# Parsing image: 000022.png
# Running model inference for frame 22
# Completed processing frame 0
# Processing frame 22
# Parsing image: 000022.png
# Running model inference for frame 22
# Completed processing frame 1
# Processing frame 23
# Parsing image: 000023.png
# Running model inference for frame 23
# Completed processing frame 6
# Processing frame 23
# Parsing image: 000023.png
# Running model inference for frame 23
# Completed processing frame 0
# Processing frame 22
# Parsing image: 000022.png
# Running model inference for frame 22
# Completed processing frame 9
# Processing frame 23
# Parsing image: 000023.png
# Running model inference for frame 23
# Completed processing frame 13
# Completed processing frame 4
# Processing frame 23
# Parsing image: 000023.png
# Processing frame 24
# Parsing image: 000024.png
# Running model inference for frame 23
# Running model inference for frame 24
# Processing triplet 2 with confidence 0.783 in frame 15
# Processing triplet 2 with confidence 0.504 in frame 13
# Completed processing frame 12
# Processing frame 24
# Parsing image: 000024.png
# Running model inference for frame 24
# Processing triplet 2 with confidence 0.573 in frame 14
# Processing triplet 2 with confidence 0.562 in frame 14
# Completed processing frame 15
# Processing frame 25
# Parsing image: 000025.png
# Running model inference for frame 25
# Completed processing frame 12
# Processing frame 24
# Parsing image: 000024.png
# Running model inference for frame 24
# Found 2 confident predictions in frame 18
# Processing triplet 0 with confidence 0.599 in frame 18
# Processing triplet 2 with confidence 0.547 in frame 12
# Processing triplet 2 with confidence 0.750 in frame 14
# Completed processing frame 12
# Processing frame 24
# Parsing image: 000024.png
# Running model inference for frame 24
# Found 1 confident predictions in frame 17
# Processing triplet 0 with confidence 0.703 in frame 17
# Found 1 confident predictions in frame 19
# Processing triplet 0 with confidence 0.703 in frame 19
# Found 1 confident predictions in frame 20
# Processing triplet 0 with confidence 0.703 in frame 20
# Completed processing frame 12
# Processing frame 24
# Parsing image: 000024.png
# Running model inference for frame 24
# Completed processing frame 13
# Processing frame 26
# Parsing image: 000026.png
# Running model inference for frame 26
# Found 1 confident predictions in frame 21
# Processing triplet 0 with confidence 0.703 in frame 21
# Found 2 confident predictions in frame 20
# Processing triplet 0 with confidence 0.729 in frame 20
# Found 1 confident predictions in frame 19
# Processing triplet 0 with confidence 0.733 in frame 19
# Found 1 confident predictions in frame 22
# Processing triplet 0 with confidence 0.703 in frame 22
# Found 2 confident predictions in frame 21
# Processing triplet 0 with confidence 0.608 in frame 21
# Completed processing frame 18
# Processing frame 25
# Parsing image: 000025.png
# Found 1 confident predictions in frame 21
# Processing triplet 0 with confidence 0.536 in frame 21
# Completed processing frame 15
# Processing frame 26
# Parsing image: 000026.png
# Processing triplet 2 with confidence 0.514 in frame 13
# Completed processing frame 18
# Processing frame 25
# Parsing image: 000025.png
# Found 1 confident predictions in frame 20
# Processing triplet 0 with confidence 0.761 in frame 20
# Found 2 confident predictions in frame 21
# Processing triplet 0 with confidence 0.726 in frame 21
# Found 2 confident predictions in frame 22
# Processing triplet 0 with confidence 0.618 in frame 22
# Found 1 confident predictions in frame 22
# Processing triplet 0 with confidence 0.811 in frame 22
# Found 1 confident predictions in frame 23
# Processing triplet 0 with confidence 0.703 in frame 23
# Running model inference for frame 25
# Running model inference for frame 26
# Running model inference for frame 25
# Completed processing frame 15
# Processing frame 25
# Parsing image: 000025.png
# Running model inference for frame 25
# Completed processing frame 16Completed processing frame 16
#
# Processing frame 27
# Parsing image: 000027.png
# Processing frame 26
# Parsing image: 000026.png
# Running model inference for frame 26
# Running model inference for frame 27
# Processing triplet 2 with confidence 0.571 in frame 16
# Completed processing frame 19
# Processing frame 26
# Parsing image: 000026.png
# Completed processing frame 20
# Processing frame 27
# Parsing image: 000027.png
# Completed processing frame 13
# Running model inference for frame 26
# Processing frame 28
# Parsing image: 000028.png
# Running model inference for frame 27
# Running model inference for frame 28
# Completed processing frame 20
# Processing frame 29
# Parsing image: 000029.png
# Running model inference for frame 29
# Processing triplet 2 with confidence 0.520 in frame 16
# Completed processing frame 14
# Processing frame 30
# Parsing image: 000030.png
# Running model inference for frame 30
# Completed processing frame 17
# Processing frame 28
# Parsing image: 000028.png
# Running model inference for frame 28
# Completed processing frame 19
# Processing frame 31
# Parsing image: 000031.png
# Running model inference for frame 31
# Completed processing frame 16
# Found 2 confident predictions in frame 22
# Processing triplet 0 with confidence 0.874 in frame 22
# Processing frame 25
# Parsing image: 000025.png
# Running model inference for frame 25
# Found 1 confident predictions in frame 23
# Processing triplet 0 with confidence 0.752 in frame 23
# Completed processing frame 15
# Processing frame 26
# Parsing image: 000026.png
# Running model inference for frame 26
# Completed processing frame 21
# Processing frame 32
# Parsing image: 000032.png
# Running model inference for frame 32
# Completed processing frame 17
# Processing frame 33
# Parsing image: 000033.png
# Processing triplet 2 with confidence 0.623 in frame 18
# Running model inference for frame 33
# Completed processing frame 19
# Processing frame 27
# Parsing image: 000027.png
# Found 2 confident predictions in frame 23
# Processing triplet 0 with confidence 0.824 in frame 23
# Running model inference for frame 27
# Found 2 confident predictions in frame 23
# Processing triplet 0 with confidence 0.742 in frame 23
# Found 2 confident predictions in frame 24
# Processing triplet 0 with confidence 0.692 in frame 24
# Completed processing frame 17
# Completed processing frame 23
# Processing frame 34
# Parsing image: 000034.png
# Processing frame 28
# Parsing image: 000028.png
# Running model inference for frame 34
# Running model inference for frame 28
# Processing triplet 6 with confidence 0.528 in frame 17
# Processing triplet 2 with confidence 0.561 in frame 14
# Completed processing frame 18
# Processing frame 27
# Parsing image: 000027.png
# Running model inference for frame 27
# Found 2 confident predictions in frame 24
# Processing triplet 0 with confidence 0.768 in frame 24
# Completed processing frame 22
# Processing frame 35
# Parsing image: 000035.png
# Found 2 confident predictions in frame 25
# Processing triplet 0 with confidence 0.840 in frame 25
# Running model inference for frame 35
# Found 2 confident predictions in frame 24
# Processing triplet 0 with confidence 0.653 in frame 24
# Found 1 confident predictions in frame 24
# Processing triplet 0 with confidence 0.703 in frame 24
# Found 1 confident predictions in frame 24
# Processing triplet 0 with confidence 0.703 in frame 24
# Found 2 confident predictions in frame 26
# Processing triplet 0 with confidence 0.567 in frame 26
# Found 1 confident predictions in frame 26
# Processing triplet 0 with confidence 0.703 in frame 26
# Found 1 confident predictions in frame 25
# Processing triplet 0 with confidence 0.820 in frame 25
# Found 1 confident predictions in frame 25
# Processing triplet 0 with confidence 0.703 in frame 25
# Found 2 confident predictions in frame 26
# Processing triplet 0 with confidence 0.707 in frame 26
# Found 1 confident predictions in frame 25
# Processing triplet 0 with confidence 0.744 in frame 25
# Found 1 confident predictions in frame 27Found 1 confident predictions in frame 29
# Processing triplet 0 with confidence 0.703 in frame 29
#
# Processing triplet 0 with confidence 0.703 in frame 27
# Found 1 confident predictions in frame 26
# Processing triplet 0 with confidence 0.833 in frame 26
# Found 1 confident predictions in frame 27
# Processing triplet 0 with confidence 0.536 in frame 27
# Found 1 confident predictions in frame 28
# Processing triplet 0 with confidence 0.703 in frame 28
# Found 1 confident predictions in frame 30
# Processing triplet 0 with confidence 0.703 in frame 30
# Found 2 confident predictions in frame 27
# Processing triplet 0 with confidence 0.732 in frame 27
# Found 1 confident predictions in frame 28
# Processing triplet 0 with confidence 0.848 in frame 28
# Found 1 confident predictions in frame 25
# Processing triplet 0 with confidence 0.703 in frame 25
# Found 1 confident predictions in frame 31
# Processing triplet 0 with confidence 0.703 in frame 31
# Found 1 confident predictions in frame 33
# Processing triplet 0 with confidence 0.703 in frame 33
# Found 1 confident predictions in frame 32Found 1 confident predictions in frame 26
# Processing triplet 0 with confidence 0.703 in frame 26
#
# Processing triplet 0 with confidence 0.703 in frame 32
# Found 2 confident predictions in frame 28
# Processing triplet 0 with confidence 0.621 in frame 28
# Found 1 confident predictions in frame 34
# Processing triplet 0 with confidence 0.703 in frame 34
# Found 1 confident predictions in frame 27
# Processing triplet 0 with confidence 0.703 in frame 27
# Found 1 confident predictions in frame 35
# Processing triplet 0 with confidence 0.703 in frame 35
# Completed processing frame 15
# Processing frame 29
# Parsing image: 000029.png
# Completed processing frame 13
# Processing frame 28
# Parsing image: 000028.png
# Running model inference for frame 29
# Running model inference for frame 28
# Processing triplet 2 with confidence 0.570 in frame 18
# Completed processing frame 14
# Processing frame 29
# Parsing image: 000029.png
# Running model inference for frame 29
# Completed processing frame 14
# Processing frame 29
# Parsing image: 000029.png
# Running model inference for frame 29
# Completed processing frame 12
# Processing frame 30
# Parsing image: 000030.png
# Running model inference for frame 30
# Completed processing frame 17
# Processing frame 27
# Parsing image: 000027.png
# Running model inference for frame 27
# Completed processing frame 19
# Processing frame 30
# Parsing image: 000030.png
# Running model inference for frame 30
# Completed processing frame 20
# Processing frame 31
# Parsing image: 000031.png
# Running model inference for frame 31
# Completed processing frame 14
# Processing frame 31
# Parsing image: 000031.png
# Running model inference for frame 31
# Processing triplet 2 with confidence 0.588 in frame 20Completed processing frame 21
# Processing frame 32
# Parsing image: 000032.png
#
# Completed processing frame 21
# Processing frame 30
# Parsing image: 000030.png
# Running model inference for frame 32Running model inference for frame 30
#
# Completed processing frame 22
# Processing frame 33
# Parsing image: 000033.png
# Processing triplet 2 with confidence 0.724 in frame 21
# Running model inference for frame 33
# Completed processing frame 23
# Processing frame 34
# Parsing image: 000034.png
# Completed processing frame 13
# Running model inference for frame 34
# Processing triplet 2 with confidence 0.685 in frame 22
# Processing frame 28
# Parsing image: 000028.png
# Completed processing frame 20
# Processing frame 29
# Parsing image: 000029.png
# Completed processing frame 19
# Running model inference for frame 28
# Processing frame 30
# Parsing image: 000030.png
# Running model inference for frame 29
# Running model inference for frame 30
# Processing triplet 2 with confidence 0.607 in frame 21
# Completed processing frame 16
# Processing frame 32
# Parsing image: 000032.png
# Running model inference for frame 32
# Completed processing frame 22
# Processing frame 31
# Parsing image: 000031.png
# Running model inference for frame 31
# Processing triplet 2 with confidence 0.770 in frame 22
# Completed processing frame 16
# Processing frame 31
# Parsing image: 000031.png
# Running model inference for frame 31
# Processing triplet 2 with confidence 0.618 in frame 24
# Processing triplet 2 with confidence 0.554 in frame 23
# Completed processing frame 23
# Processing frame 32
# Parsing image: 000032.png
# Running model inference for frame 32
# Completed processing frame 18
# Processing frame 32
# Parsing image: 000032.png
# Running model inference for frame 32
# Found 2 confident predictions in frame 29
# Processing triplet 0 with confidence 0.866 in frame 29
# Found 1 confident predictions in frame 29
# Processing triplet 0 with confidence 0.703 in frame 29
# Processing triplet 2 with confidence 0.672 in frame 23
# Found 1 confident predictions in frame 28
# Processing triplet 0 with confidence 0.703 in frame 28
# Completed processing frame 17
# Processing frame 35
# Parsing image: 000035.png
# Running model inference for frame 35
# Completed processing frame 14
# Processing frame 33
# Parsing image: 000033.png
# Running model inference for frame 33
# Found 2 confident predictions in frame 30
# Processing triplet 0 with confidence 0.705 in frame 30
# Found 1 confident predictions in frame 29
# Processing triplet 0 with confidence 0.520 in frame 29
# Found 1 confident predictions in frame 27
# Processing triplet 0 with confidence 0.835 in frame 27
# Processing triplet 2 with confidence 0.560 in frame 25
# Processing triplet 2 with confidence 0.574 in frame 24
# Processing triplet 2 with confidence 0.594 in frame 24
# Completed processing frame 24
# Processing frame 36
# Parsing image: 000036.png
# Completed processing frame 24
# Processing frame 36
# Parsing image: 000036.png
# Found 1 confident predictions in frame 30
# Processing triplet 0 with confidence 0.703 in frame 30
# Found 1 confident predictions in frame 31
# Processing triplet 0 with confidence 0.742 in frame 31
# Found 1 confident predictions in frame 32
# Processing triplet 0 with confidence 0.703 in frame 32
# Found 1 confident predictions in frame 31
# Processing triplet 0 with confidence 0.703 in frame 31
# Found 1 confident predictions in frame 30
# Processing triplet 0 with confidence 0.648 in frame 30
# Running model inference for frame 36
# Running model inference for frame 36
# Processing triplet 2 with confidence 0.563 in frame 26
# Completed processing frame 25
# Processing frame 37
# Parsing image: 000037.png
# Running model inference for frame 37
# Completed processing frame 26
# Processing frame 38
# Parsing image: 000038.png
# Running model inference for frame 38
# Found 1 confident predictions in frame 34
# Processing triplet 0 with confidence 0.703 in frame 34
# Found 3 confident predictions in frame 30
# Processing triplet 0 with confidence 0.711 in frame 30
# Found 1 confident predictions in frame 33
# Processing triplet 0 with confidence 0.703 in frame 33
# Found 2 confident predictions in frame 29
# Processing triplet 0 with confidence 0.554 in frame 29
# Completed processing frame 27
# Processing frame 39
# Parsing image: 000039.png
# Running model inference for frame 39
# Completed processing frame 25
# Processing triplet 2 with confidence 0.601 in frame 27
# Processing frame 33
# Parsing image: 000033.png
# Found 1 confident predictions in frame 28
# Processing triplet 0 with confidence 0.738 in frame 28
# Running model inference for frame 33
# Processing triplet 2 with confidence 0.597 in frame 26
# Completed processing frame 27
# Processing frame 34
# Parsing image: 000034.png
# Running model inference for frame 34
# Completed processing frame 29
# Processing frame 40
# Parsing image: 000040.png
# Completed processing frame 28
# Processing frame 35
# Parsing image: 000035.png
# Running model inference for frame 40
# Completed processing frame 31
# Processing frame 41
# Parsing image: 000041.png
# Completed processing frame 25
# Processing frame 34
# Parsing image: 000034.png
# Running model inference for frame 35Running model inference for frame 34
# Running model inference for frame 41
#
# Completed processing frame 25
# Processing frame 37
# Parsing image: 000037.png
# Completed processing frame 28
# Completed processing frame 33
# Processing frame 42
# Parsing image: 000042.png
# Processing frame 43
# Parsing image: 000043.png
# Found 1 confident predictions in frame 31
# Processing triplet 0 with confidence 0.764 in frame 31
# Found 1 confident predictions in frame 32
# Processing triplet 0 with confidence 0.596 in frame 32
# Running model inference for frame 42
# Running model inference for frame 37
# Running model inference for frame 43
# Completed processing frame 26
# Processing frame 38
# Parsing image: 000038.png
# Completed processing frame 26
# Processing frame 36
# Parsing image: 000036.png
# Completed processing frame 30
# Processing frame 44
# Parsing image: 000044.png
# Found 2 confident predictions in frame 31
# Processing triplet 0 with confidence 0.514 in frame 31
# Running model inference for frame 36
# Running model inference for frame 38
# Found 2 confident predictions in frame 32
# Processing triplet 0 with confidence 0.767 in frame 32
# Running model inference for frame 44
# Completed processing frame 32
# Processing frame 45
# Parsing image: 000045.png
# Running model inference for frame 45
# Completed processing frame 35
# Processing frame 46
# Parsing image: 000046.png
# Running model inference for frame 46
# Processing triplet 2 with confidence 0.565 in frame 28
# Completed processing frame 34
# Processing frame 47
# Parsing image: 000047.png
# Completed processing frame 27
# Processing frame 39
# Parsing image: 000039.png
# Running model inference for frame 47
# Running model inference for frame 39
# Found 1 confident predictions in frame 32
# Processing triplet 0 with confidence 0.503 in frame 32
# Found 1 confident predictions in frame 35
# Processing triplet 0 with confidence 0.703 in frame 35
# Found 1 confident predictions in frame 36
# Processing triplet 0 with confidence 0.703 in frame 36
# Found 1 confident predictions in frame 33
# Processing triplet 0 with confidence 0.818 in frame 33
# Found 1 confident predictions in frame 36
# Processing triplet 0 with confidence 0.703 in frame 36
# Completed processing frame 18
# Processing frame 35
# Parsing image: 000035.png
# Found 1 confident predictions in frame 37
# Processing triplet 0 with confidence 0.703 in frame 37
# Found 1 confident predictions in frame 38
# Processing triplet 0 with confidence 0.703 in frame 38
# Found 1 confident predictions in frame 39
# Processing triplet 0 with confidence 0.703 in frame 39
# Running model inference for frame 35
# Completed processing frame 20
# Processing frame 33
# Parsing image: 000033.png
# Running model inference for frame 33
# Found 2 confident predictions in frame 33
# Processing triplet 0 with confidence 0.632 in frame 33
# Found 1 confident predictions in frame 40
# Processing triplet 0 with confidence 0.703 in frame 40
# Completed processing frame 21
# Found 1 confident predictions in frame 42
# Processing triplet 0 with confidence 0.703 in frame 42
# Processing frame 37
# Parsing image: 000037.png
# Running model inference for frame 37
# Found 1 confident predictions in frame 43
# Processing triplet 0 with confidence 0.703 in frame 43
# Found 1 confident predictions in frame 44
# Processing triplet 0 with confidence 0.703 in frame 44
# Completed processing frame 22
# Processing frame 34
# Parsing image: 000034.png
# Found 2 confident predictions in frame 35
# Processing triplet 0 with confidence 0.770 in frame 35
# Found 2 confident predictions in frame 36
# Processing triplet 0 with confidence 0.691 in frame 36
# Found 1 confident predictions in frame 34
# Processing triplet 0 with confidence 0.869 in frame 34
# Found 1 confident predictions in frame 34
# Processing triplet 0 with confidence 0.899 in frame 34
# Found 1 confident predictions in frame 37
# Processing triplet 0 with confidence 0.703 in frame 37
# Running model inference for frame 34
# Found 2 confident predictions in frame 38
# Processing triplet 0 with confidence 0.758 in frame 38
# Completed processing frame 21
# Found 1 confident predictions in frame 41
# Processing triplet 0 with confidence 0.703 in frame 41
# Processing frame 36
# Parsing image: 000036.png
# Found 1 confident predictions in frame 45
# Processing triplet 0 with confidence 0.703 in frame 45
# Running model inference for frame 36
# Found 1 confident predictions in frame 46
# Processing triplet 0 with confidence 0.703 in frame 46
# Found 1 confident predictions in frame 47
# Processing triplet 0 with confidence 0.703 in frame 47
# Found 2 confident predictions in frame 39
# Processing triplet 0 with confidence 0.810 in frame 39
# Completed processing frame 22
# Processing frame 38
# Parsing image: 000038.png
# Running model inference for frame 38
# Completed processing frame 24
# Processing frame 39
# Parsing image: 000039.png
# Running model inference for frame 39
# Completed processing frame 23
# Processing frame 40
# Parsing image: 000040.png
# Completed processing frame 28
# Processing frame 40
# Parsing image: 000040.png
# Found 1 confident predictions in frame 35
# Processing triplet 0 with confidence 0.513 in frame 35
# Running model inference for frame 40
# Running model inference for frame 40
# Completed processing frame 23
# Processing frame 35
# Parsing image: 000035.png
# Completed processing frame 30
# Running model inference for frame 35
# Processing frame 36
# Parsing image: 000036.png
# Completed processing frame 31
# Processing frame 41
# Parsing image: 000041.png
# Running model inference for frame 36
# Completed processing frame 25
# Processing frame 37
# Parsing image: 000037.png
# Completed processing frame 27
# Completed processing frame 31
# Processing frame 37
# Parsing image: 000037.png
# Processing frame 41
# Parsing image: 000041.png
# Completed processing frame 29
# Processing frame 42
# Parsing image: 000042.png
# Processing triplet 2 with confidence 0.641 in frame 29
# Completed processing frame 24
# Processing frame 38
# Parsing image: 000038.png
# Completed processing frame 29
# Processing frame 38
# Parsing image: 000038.png
# Completed processing frame 32
# Processing frame 43
# Parsing image: 000043.png
# Completed processing frame 30
# Processing frame 44
# Parsing image: 000044.png
# Completed processing frame 24
# Processing triplet 2 with confidence 0.533 in frame 30
# Processing frame 39
# Parsing image: 000039.png
# Found 2 confident predictions in frame 33
# Processing triplet 0 with confidence 0.800 in frame 33
# Running model inference for frame 39
# Running model inference for frame 38
# Running model inference for frame 43
# Running model inference for frame 38
# Running model inference for frame 41
# Running model inference for frame 37
# Running model inference for frame 37
# Running model inference for frame 42
# Running model inference for frame 44
# Running model inference for frame 41
# Completed processing frame 26
# Processing frame 40
# Parsing image: 000040.png
# Running model inference for frame 40
# Completed processing frame 34
# Processing frame 45
# Parsing image: 000045.png
# Found 2 confident predictions in frame 34
# Processing triplet 0 with confidence 0.678 in frame 34
# Running model inference for frame 45
# Completed processing frame 27
# Completed processing frame 28
# Processing frame 39
# Parsing image: 000039.png
# Processing frame 41
# Parsing image: 000041.png
# Running model inference for frame 41
# Running model inference for frame 39
# Found 2 confident predictions in frame 36
# Processing triplet 0 with confidence 0.657 in frame 36
# Found 2 confident predictions in frame 37
# Processing triplet 0 with confidence 0.802 in frame 37
# Processing triplet 1 with confidence 0.522 in frame 30
# Completed processing frame 33
# Processing frame 46
# Parsing image: 000046.png
# Running model inference for frame 46
# Processing triplet 2 with confidence 0.806 in frame 29
# Completed processing frame 31
# Processing frame 40
# Parsing image: 000040.png
# Running model inference for frame 40
# Completed processing frame 26
# Processing frame 41
# Parsing image: 000041.png
# Running model inference for frame 41
# Processing triplet 2 with confidence 0.571 in frame 32Completed processing frame 32
#
# Processing frame 42
# Parsing image: 000042.png
# Running model inference for frame 42
# Processing triplet 2 with confidence 0.518 in frame 31
# Found 1 confident predictions in frame 38
# Processing triplet 0 with confidence 0.827 in frame 38
# Found 1 confident predictions in frame 39
# Processing triplet 0 with confidence 0.838 in frame 39
# Found 1 confident predictions in frame 40
# Processing triplet 0 with confidence 0.757 in frame 40
# Completed processing frame 28
# Processing frame 42
# Parsing image: 000042.png
# Running model inference for frame 42
# Found 1 confident predictions in frame 40
# Processing triplet 0 with confidence 0.821 in frame 40
# Found 2 confident predictions in frame 43
# Processing triplet 0 with confidence 0.650 in frame 43
# Found 2 confident predictions in frame 38
# Processing triplet 0 with confidence 0.853 in frame 38
# Found 2 confident predictions in frame 42
# Processing triplet 0 with confidence 0.710 in frame 42
# Found 1 confident predictions in frame 36
# Processing triplet 0 with confidence 0.816 in frame 36
# Found 1 confident predictions in frame 38
# Processing triplet 0 with confidence 0.668 in frame 38
# Found 1 confident predictions in frame 41
# Processing triplet 0 with confidence 0.713 in frame 41
# Found 1 confident predictions in frame 35
# Processing triplet 0 with confidence 0.756 in frame 35
# Found 1 confident predictions in frame 37
# Processing triplet 0 with confidence 0.750 in frame 37
# Found 1 confident predictions in frame 44
# Processing triplet 0 with confidence 0.801 in frame 44
# Found 2 confident predictions in frame 41
# Processing triplet 0 with confidence 0.514 in frame 41
# Found 1 confident predictions in frame 37
# Processing triplet 0 with confidence 0.719 in frame 37
# Completed processing frame 35
# Processing frame 47
# Parsing image: 000047.png
# Found 1 confident predictions in frame 39
# Processing triplet 0 with confidence 0.632 in frame 39
# Running model inference for frame 47
# Completed processing frame 32
# ...
# Found 1 confident predictions in frame 2174
# Processing triplet 0 with confidence 0.703 in frame 2174
# Completed processing frame 2170
# Found 1 confident predictions in frame 2138
# Processing triplet 0 with confidence 0.703 in frame 2138
# Completed processing frame 2095
# Processing frame 2111
# Parsing image: 002111.png
# Running model inference for frame 2111
# Found 1 confident predictions in frame 2175
# Processing triplet 0 with confidence 0.703 in frame 2175
# Found 1 confident predictions in frame 2140
# Processing triplet 0 with confidence 0.703 in frame 2140
# Found 1 confident predictions in frame 2139
# Processing triplet 0 with confidence 0.703 in frame 2139
# Found 1 confident predictions in frame 2141
# Processing triplet 0 with confidence 0.703 in frame 2141
# Completed processing frame 2172
# Found 1 confident predictions in frame 2176
# Processing triplet 0 with confidence 0.703 in frame 2176
# Found 1 confident predictions in frame 2109
# Processing triplet 0 with confidence 0.703 in frame 2109
# Found 1 confident predictions in frame 2110
# Processing triplet 0 with confidence 0.703 in frame 2110
# Completed processing frame 2165
# Processing frame 2177
# Parsing image: 002177.png
# Running model inference for frame 2177
# Completed processing frame 2166
# Processing frame 2178
# Parsing image: 002178.png
# Running model inference for frame 2178
# Completed processing frame 2132
# Processing frame 2143
# Parsing image: 002143.png
# Processing triplet 2 with confidence 0.601 in frame 2103
# Completed processing frame 2131
# Processing frame 2144
# Parsing image: 002144.png
# Running model inference for frame 2143
# Running model inference for frame 2144
# Found 1 confident predictions in frame 2142
# Processing triplet 0 with confidence 0.703 in frame 2142
# Completed processing frame 2167
# Processing frame 2179
# Parsing image: 002179.png
# Running model inference for frame 2179
# Completed processing frame 2173
# Completed processing frame 2133
# Processing frame 2145
# Parsing image: 002145.png
# Running model inference for frame 2145
# Completed processing frame 2174
# Completed processing frame 2175
# Completed processing frame 2169
# Processing frame 2180
# Parsing image: 002180.png
# Running model inference for frame 2180
# Found 1 confident predictions in frame 2111
# Processing triplet 0 with confidence 0.703 in frame 2111
# Completed processing frame 2168
# Processing frame 2181
# Parsing image: 002181.png
# Running model inference for frame 2181
# Completed processing frame 2134
# Completed processing frame 2176
# Completed processing video: VID110
# Completed processing frame 2170
# Processing frame 2182
# Parsing image: 002182.png
# Completed processing frame 2098
# Running model inference for frame 2182
# Processing frame 2112
# Parsing image: 002112.png
# Running model inference for frame 2112
# Completed processing frame 2171
# Processing frame 2183
# Parsing image: 002183.png
# Running model inference for frame 2183
# Completed processing frame 2105
# Processing frame 2113
# Parsing image: 002113.png
# Running model inference for frame 2113
# Completed processing frame 2135
# Found 1 confident predictions in frame 2177Processing triplet 2 with confidence 0.645 in frame 2104
#
# Processing triplet 0 with confidence 0.703 in frame 2177
# Completed processing frame 2099
# Processing frame 2114
# Parsing image: 002114.png
# Running model inference for frame 2114
# Found 1 confident predictions in frame 2178
# Processing triplet 0 with confidence 0.703 in frame 2178
# Found 1 confident predictions in frame 2143
# Processing triplet 0 with confidence 0.703 in frame 2143
# Found 1 confident predictions in frame 2144
# Processing triplet 0 with confidence 0.703 in frame 2144
# Completed processing frame 2102
# Processing frame 2115
# Parsing image: 002115.png
# Completed processing frame 2106
# Processing frame 2116
# Parsing image: 002116.png
# Running model inference for frame 2116
# Running model inference for frame 2115
# Completed processing frame 2107
# Processing frame 2117
# Parsing image: 002117.png
# Running model inference for frame 2117
# Completed processing frame 2172
# Processing frame 2184
# Parsing image: 002184.png
# Running model inference for frame 2184
# Found 1 confident predictions in frame 2179
# Processing triplet 0 with confidence 0.703 in frame 2179
# Found 1 confident predictions in frame 2145
# Processing triplet 0 with confidence 0.703 in frame 2145
# Completed processing frame 2136
# Completed processing frame 2137
# Completed processing frame 2174
# Completed processing frame 2173
# Processing frame 2185
# Parsing image: 002185.png
# Processing frame 2186
# Parsing image: 002186.png
# Running model inference for frame 2186
# Running model inference for frame 2185
# Found 1 confident predictions in frame 2180
# Processing triplet 0 with confidence 0.703 in frame 2180
# Completed processing frame 2108
# Processing frame 2118
# Parsing image: 002118.png
# Running model inference for frame 2118
# Found 1 confident predictions in frame 2181
# Processing triplet 0 with confidence 0.703 in frame 2181
# Completed processing frame 2175
# Processing frame 2187
# Parsing image: 002187.png
# Found 1 confident predictions in frame 2182
# Processing triplet 0 with confidence 0.703 in frame 2182
# Running model inference for frame 2187
# Completed processing frame 2138
# Found 1 confident predictions in frame 2112
# Processing triplet 0 with confidence 0.703 in frame 2112
# Completed processing frame 2140
# Completed processing frame 2139
# Found 1 confident predictions in frame 2113
# Processing triplet 0 with confidence 0.703 in frame 2113
# Found 1 confident predictions in frame 2183
# Processing triplet 0 with confidence 0.703 in frame 2183
# Found 1 confident predictions in frame 2114
# Processing triplet 0 with confidence 0.703 in frame 2114
# Completed processing frame 2141
# Completed processing frame 2176
# Processing frame 2188
# Parsing image: 002188.png
# Found 1 confident predictions in frame 2115
# Processing triplet 0 with confidence 0.703 in frame 2115
# Running model inference for frame 2188
# Found 1 confident predictions in frame 2116
# Processing triplet 0 with confidence 0.703 in frame 2116
# Completed processing frame 2110
# Processing frame 2119
# Parsing image: 002119.png
# Completed processing frame 2109
# Running model inference for frame 2119
# Processing frame 2120
# Parsing image: 002120.png
# Running model inference for frame 2120
# Found 1 confident predictions in frame 2117
# Processing triplet 0 with confidence 0.703 in frame 2117
# Found 1 confident predictions in frame 2184
# Processing triplet 0 with confidence 0.703 in frame 2184
# Completed processing frame 2103
# Processing frame 2121
# Parsing image: 002121.png
# Running model inference for frame 2121
# Completed processing frame 2142
# Found 1 confident predictions in frame 2185
# Processing triplet 0 with confidence 0.703 in frame 2185
# Found 1 confident predictions in frame 2186
# Processing triplet 0 with confidence 0.703 in frame 2186
# Found 1 confident predictions in frame 2118
# Processing triplet 0 with confidence 0.703 in frame 2118
# Found 1 confident predictions in frame 2187
# Processing triplet 0 with confidence 0.703 in frame 2187
# Completed processing frame 2111
# Processing frame 2122
# Parsing image: 002122.png
# Running model inference for frame 2122
# Found 1 confident predictions in frame 2188
# Processing triplet 0 with confidence 0.703 in frame 2188
# Completed processing frame 2178
# Processing frame 2189
# Parsing image: 002189.png
# Found 1 confident predictions in frame 2119
# Processing triplet 0 with confidence 0.703 in frame 2119
# Running model inference for frame 2189
# Found 1 confident predictions in frame 2120
# Processing triplet 0 with confidence 0.703 in frame 2120
# Completed processing frame 2177
# Processing frame 2190
# Parsing image: 002190.png
# Running model inference for frame 2190
# Completed processing frame 2104
# Processing frame 2123
# Parsing image: 002123.png
# Running model inference for frame 2123
# Completed processing frame 2143
# Completed processing frame 2144
# Found 1 confident predictions in frame 2121
# Processing triplet 0 with confidence 0.703 in frame 2121
# Completed processing frame 2179
# Processing frame 2191
# Parsing image: 002191.png
# Running model inference for frame 2191
# Completed processing frame 2145
# Completed processing video: VID111
# Completed processing frame 2180
# Processing frame 2192
# Parsing image: 002192.png
# Running model inference for frame 2192
# Found 1 confident predictions in frame 2122
# Processing triplet 0 with confidence 0.703 in frame 2122
# Completed processing frame 2112
# Completed processing frame 2181
# Processing frame 2193
# Parsing image: 002193.png
# Running model inference for frame 2193
# Completed processing frame 2182
# Processing frame 2194
# Parsing image: 002194.png
# Running model inference for frame 2194
# Found 1 confident predictions in frame 2189
# Processing triplet 0 with confidence 0.703 in frame 2189
# Completed processing frame 2183
# Processing frame 2195
# Parsing image: 002195.png
# Running model inference for frame 2195
# Completed processing frame 2113
# Found 1 confident predictions in frame 2123
# Processing triplet 0 with confidence 0.703 in frame 2123
# Completed processing frame 2114
# Found 1 confident predictions in frame 2190
# Processing triplet 0 with confidence 0.703 in frame 2190
# Completed processing frame 2115
# Completed processing frame 2116
# Completed processing frame 2117
# Completed processing frame 2184
# Processing frame 2196
# Parsing image: 002196.png
# Running model inference for frame 2196
# Found 1 confident predictions in frame 2191
# Processing triplet 0 with confidence 0.703 in frame 2191
# Completed processing frame 2186
# Processing frame 2197
# Parsing image: 002197.png
# Found 1 confident predictions in frame 2192
# Processing triplet 0 with confidence 0.703 in frame 2192
# Running model inference for frame 2197
# Completed processing frame 2185
# Processing frame 2198
# Parsing image: 002198.png
# Running model inference for frame 2198
# Completed processing frame 2118
# Found 1 confident predictions in frame 2193
# Processing triplet 0 with confidence 0.703 in frame 2193
# Found 1 confident predictions in frame 2194
# Processing triplet 0 with confidence 0.703 in frame 2194
# Completed processing frame 2187
# Processing frame 2199
# Parsing image: 002199.png
# Running model inference for frame 2199
# Found 1 confident predictions in frame 2195
# Processing triplet 0 with confidence 0.703 in frame 2195
# Completed processing frame 2188
# Processing frame 2200
# Parsing image: 002200.png
# Running model inference for frame 2200
# Completed processing frame 2119
# Completed processing frame 2120
# Found 1 confident predictions in frame 2196
# Processing triplet 0 with confidence 0.703 in frame 2196
# Completed processing frame 2121
# Found 1 confident predictions in frame 2198
# Processing triplet 0 with confidence 0.703 in frame 2198
# Found 1 confident predictions in frame 2197
# Processing triplet 0 with confidence 0.703 in frame 2197
# Found 1 confident predictions in frame 2199
# Processing triplet 0 with confidence 0.703 in frame 2199
# Completed processing frame 2122
# Found 1 confident predictions in frame 2200
# Processing triplet 0 with confidence 0.703 in frame 2200
# Completed processing frame 2189
# Processing frame 2201
# Parsing image: 002201.png
# Running model inference for frame 2201
# Completed processing frame 2190
# Processing frame 2202
# Parsing image: 002202.png
# Running model inference for frame 2202
# Completed processing frame 2123
# Completed processing video: VID92
# Completed processing video VID92
#
# Waiting for results from video VID96
# Completed processing video VID96
#
# Waiting for results from video VID103
# Completed processing frame 2191
# Processing frame 2203
# Parsing image: 002203.png
# Running model inference for frame 2203
# Completed processing frame 2193
# Processing frame 2204
# Parsing image: 002204.png
# Running model inference for frame 2204
# Completed processing frame 2192
# Processing frame 2205
# Parsing image: 002205.png
# Running model inference for frame 2205
# Completed processing frame 2194
# Processing frame 2206
# Parsing image: 002206.png
# Running model inference for frame 2206
# Completed processing frame 2195
# Processing frame 2207
# Parsing image: 002207.png
# Running model inference for frame 2207
# Found 1 confident predictions in frame 2202
# Processing triplet 0 with confidence 0.703 in frame 2202
# Found 1 confident predictions in frame 2201
# Processing triplet 0 with confidence 0.703 in frame 2201
# Found 1 confident predictions in frame 2203
# Processing triplet 0 with confidence 0.703 in frame 2203
# Completed processing frame 2196
# Processing frame 2208
# Parsing image: 002208.png
# Running model inference for frame 2208
# Completed processing frame 2198
# Processing frame 2209
# Parsing image: 002209.png
# Found 1 confident predictions in frame 2204
# Processing triplet 0 with confidence 0.703 in frame 2204
# Running model inference for frame 2209
# Found 1 confident predictions in frame 2205
# Processing triplet 0 with confidence 0.703 in frame 2205
# Completed processing frame 2197
# Processing frame 2210
# Parsing image: 002210.png
# Running model inference for frame 2210
# Found 1 confident predictions in frame 2206
# Processing triplet 0 with confidence 0.703 in frame 2206
# Completed processing frame 2199
# Processing frame 2211
# Parsing image: 002211.png
# Running model inference for frame 2211
# Found 1 confident predictions in frame 2207
# Processing triplet 0 with confidence 0.703 in frame 2207
# Completed processing frame 2200
# Processing frame 2212
# Parsing image: 002212.png
# Running model inference for frame 2212
# Found 1 confident predictions in frame 2208
# Processing triplet 0 with confidence 0.703 in frame 2208
# Found 1 confident predictions in frame 2209
# Processing triplet 0 with confidence 0.703 in frame 2209
# Found 1 confident predictions in frame 2210
# Processing triplet 0 with confidence 0.703 in frame 2210
# Found 1 confident predictions in frame 2211
# Processing triplet 0 with confidence 0.703 in frame 2211
# Found 1 confident predictions in frame 2212
# Processing triplet 0 with confidence 0.703 in frame 2212
# Completed processing frame 2202
# Processing frame 2213
# Parsing image: 002213.png
# Running model inference for frame 2213
# Completed processing frame 2201
# Processing frame 2214
# Parsing image: 002214.png
# Running model inference for frame 2214
# Completed processing frame 2203
# Processing frame 2215
# Parsing image: 002215.png
# Running model inference for frame 2215
# Completed processing frame 2205
# Processing frame 2216
# Parsing image: 002216.png
# Completed processing frame 2204
# Processing frame 2217
# Parsing image: 002217.png
# Running model inference for frame 2216
# Running model inference for frame 2217
# Completed processing frame 2206
# Processing frame 2218
# Parsing image: 002218.png
# Running model inference for frame 2218
# Completed processing frame 2207
# Processing frame 2219
# Parsing image: 002219.png
# Found 1 confident predictions in frame 2213
# Processing triplet 0 with confidence 0.703 in frame 2213
# Running model inference for frame 2219
# Found 1 confident predictions in frame 2214
# Processing triplet 0 with confidence 0.703 in frame 2214
# Completed processing frame 2208
# Found 1 confident predictions in frame 2215
# Processing triplet 0 with confidence 0.703 in frame 2215
# Found 1 confident predictions in frame 2217
# Processing triplet 0 with confidence 0.703 in frame 2217
# Completed processing frame 2209
# Found 1 confident predictions in frame 2218
# Processing triplet 0 with confidence 0.703 in frame 2218
# Found 1 confident predictions in frame 2216
# Processing triplet 0 with confidence 0.703 in frame 2216
# Completed processing frame 2210
# Found 1 confident predictions in frame 2219
# Processing triplet 0 with confidence 0.703 in frame 2219
# Completed processing frame 2211
# Completed processing frame 2212
# Completed processing frame 2214
# Completed processing frame 2213
# Completed processing frame 2215
# Completed processing frame 2217
# Completed processing frame 2218
# Completed processing frame 2216
# Completed processing frame 2219
# Completed processing video: VID103
# Completed processing video VID103
#
# Waiting for results from video VID110
# Completed processing video VID110
#
# Waiting for results from video VID111
# Completed processing video VID111
#
# Saving results to video_predictions.json
# Processing completed successfully
